# %% [markdown]
# ### Initial cleansing and analysis

# %% [markdown]
# ##Quotebank dataset
# In this notebook we will take the whole Quotebank dataset, filter it with a set of keywords : "gun violence, mass shooting, firearm-related violence, firearm violence" to create a gunshot violence related quotes dataset by keeping only the column of interest ('speaker', 'qids', 'date' and 'quotation'). The initial preprocessing chunk by chunk of the Quotebank dataset required a lot of resources so we ran it in parallel on Google Colab with different computers for different years to maximise time saving. The script was based on the provided Colab notebook as detailed below.
# After having queried for the keywords of interest, we removed the rows with no corresponding match in the quotation and after some further analysis decided also to drop the quotes associated to unknown speakers. We decided to not include the quotes from 2020 despite meeting the previously expained two criterias because of incompatibility issues with our second dataset. We note that the 2020 Quotebank dataset is significantly smaller than the data from the other years being therefore associated with a relatively low number of quotes.
#
# In parallel, we used the gun shootings events datasets "mass_shootings" and "accidents" from "https://www.gunviolencearchive.org/" to create a dataset of relevant gunshot violence related events. As mentioned the data for 2020 was not available and therefore we chose to keep data only from 2015 to 2019 adjusting accoringly also our handling of the gunshot violence related quotes dataset. We do not think that this represents a problem but actually a necessary action to take as the global pandemic events might have significantly affected the dynamics of mass shootings events and in particular the sensibility to gun violence events. As the media coverage was majorly dominated by COVID-related events, public speakers might have been less likely than usual to discuss about gun violence matters.

# %% [markdown]
# ##### Filtering quotations related to gun violence
# We queried the entire quotebank dataset in search of quotes containing any of a set of key words relating to gun violence. This was done in google colab to avoid having download the entire data sets onto our hard drive and to execute the code in chunks (by year) simultaneously on all our computers. We also printed a sample of the values, the shape and the number of missing values, both for the preprocessed and processed data.
# The code for the year 2019 is shown below as an example and we did the same for every year with the necessary changes in the file paths.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import bz2
import json
from os import listdir

# %%
def keyword(row):
    '''
    Filter the quotation of a particular row of a dataframe with a set of keywords.
    :param row: dataframe object
    :return: list of comma separated matching keywords
    '''
    strings = row['quotation']
    keywords = ["gun violence","mass shooting","firearm-related violence","firearm violence"]
    keyword = [key for key in keywords if key.upper() in strings.upper()]
    return ','.join(keyword)

# %%
def process_chunk(chunk, i):
    print(f'Processing chunk with {len(chunk)} rows')
    print(chunk.columns)
    print(chunk.shape)
    print(len(chunk[chunk.isna().any(axis=1)]))
    print(chunk.sample(10))
    selected_columns = chunk[["speaker", "qids", "date", "quotation"]]
    filtered_chunk= selected_columns.copy()
    filtered_chunk['keyword'] = filtered_chunk.apply(keyword, axis=1)
    print(len(filtered_chunk[filtered_chunk.isna().any(axis=1)]))
    print(filtered_chunk.sample(5))
    print(filtered_chunk.shape)
    filtered_chunk.to_pickle("/Users/Justin/Desktop/processed_dfs/2019/" + str(i) + "chunk_with_keyword.pkl", compression='infer', protocol=4)

i = 0
df_reader = pd.read_json('/Users/Justin/Desktop/quotes-2019.json-004.bz2', lines=True, compression='bz2', chunksize=1500000)
for chunk in df_reader:
    i += 1
    process_chunk(chunk, i)
# Out:
# Processing chunk with 1500000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# (1500000, 9)
# 0
#                    quoteID                                          quotation  \
# 445677   2019-06-27-042105       Impacting Sports Through Digital Integration
# 596011   2019-02-10-030638  I've been working with Mark Ramprakash (the ba...
# 1172386  2019-07-28-002372  As a parent you must be able to know your chil...
# 910582   2019-12-03-099056             want France taxing American companies.
# 1437171  2019-11-12-114778  When he told me that he was approached for Big...
# 793696   2019-01-28-038906  If Ginny Ramsay and her team need more, we wil...
# 1070397  2019-04-04-105396  Their support comes from an unconditional plac...
# 44060    2019-05-09-013370  But Prime Minister Imran Khan has maintained t...
# 1342566  2019-01-27-004852  Because often there's a bigger, or at least mo...
# ...

# %% [markdown]
# The next step was to create the final dataframe by filtering out the rows which didn't contain a keyword. We also filtered out any quote with undetermined speaker ("None" in the data). We noticed that a good portion of the rows retrieved have a missing speaker (hence the probability of the speaker being "unknown" is the highest). For ex just for 2020, 90 out of 336 are without speakers. However, after having initially investigated to use the QIDs to try to match some unknown speakers to potential match, we decided that all the biases in the dataset inheritated from the machine learning model should not significantly influences our analysis. We don't really need to assign all the missing speakers as we already have a large dataset of assigned gunshot violence related quotes and would like to explore the potential shift in relevant public figures' quotes concerning gun violence after significant mass shooting events.
#
# Nevertheless we ran some tests on the data with the unkwown speakers still present and it appears that quotes with no attributed speakers do not seem to differ in terms of word counts statistics from the rest of the data. Since our work will be based on a sentimental analysis, keeping those unassigned quotes seemed useless. This filtering was done with the following code, which we also previously ran on Google Collab:

# %%
DATA_PATH = '/Users/Justin/Desktop/processed_dfs/' 

def process_data(path, year, list_dfs):
    while year < 2020:
        for file in listdir(path + str(year) + '/'):
            small_df=pd.read_pickle(DATA_PATH + str(year) + '/' + file, compression='infer')
            filtered_small_df = small_df.query("keyword == 'gun violence' | keyword == 'mass shooting' | keyword == 'firearm-related violence' | keyword == 'firearm violence'")
            list_dfs.append(filtered_small_df)
    year += 1
    return list_dfs

list_dfs = []
df = pd.concat(process_data(DATA_PATH, 2019, list_dfs), ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/vy/_7j1nknd3_nb66nrqm6sk49h0000gn/T/ipykernel_46535/1043345152.py in <module>
#      11
#      12 list_dfs = []
# ---> 13 df = pd.concat(process_data(DATA_PATH, 2019, list_dfs), ignore_index=True)
#      14
#      15
#
# /var/folders/vy/_7j1nknd3_nb66nrqm6sk49h0000gn/T/ipykernel_46535/1043345152.py in process_data(path, year, list_dfs)
#       3 def process_data(path, year, list_dfs):
#       4     while year < 2020:
# ----> 5         for file in listdir(path + str(year) + '/'):
#       6             small_df=pd.read_pickle(DATA_PATH + str(year) + '/' + file, compression='infer')
#       7             filtered_small_df = small_df.query("keyword == 'gun violence' | keyword == 'mass shooting' | keyword == 'firearm-related violence' | keyword == 'firearm violence'")
#
# KeyboardInterrupt:

# %% [markdown]
# We then proceeded to print the dataframe shape, the number of potential missing values as well as counting how many missing speakers instance are in our data and the number of unique speakers (including None and not discriminating for diverse speaker labels referring to the same person like the 'President Obama case'). We have about 20 thousand assigned speakers with roughly 10 thousand unknown ones.
#
# We then counted the number of words for each quotation after having lowercased and polished the strings and added the results in a new column named 'Words count'. These values could come handy also later for the sentimental analysis.

# %%
print(df.sample(10))
print(df.shape)
print(len(df[df.isna().any(axis=1)]))
print(df['speaker'].eq('None').sum())
print(df['speaker'].nunique())

df['quotation'] = df['quotation'].apply(lambda x: x.lower())
df['quotation'] = df['quotation'].replace('\d+', '', regex = True)
df['quotation'] = df['quotation'].replace('[^\w\s\+]', '', regex = True)
df['Words count'] = df['quotation'].apply(lambda x: len(str(x).split(' ')))
# Out:
#                         speaker         qids  ...        keyword Words count
# 17817             Mark Hastings  [Q27058474]  ...  mass shooting          43
# 7607                Seth Meyers     [Q14536]  ...   gun violence          15
# 11237             Emma González  [Q49560460]  ...   gun violence           8
# 1616                       None           []  ...   gun violence           7
# 26597                Kris Brown   [Q1619393]  ...   gun violence          32
# 30002           Fred Guttenberg  [Q50380052]  ...   gun violence          28
# 201             Hillary Clinton      [Q6294]  ...   gun violence          31
# 3180               Suzanna Hupp   [Q7650729]  ...  mass shooting          12
# 27385  Alexandria Ocasio-Cortez  [Q55223040]  ...  mass shooting          18
# 3487            Nydia Velazquez    [Q434890]  ...   gun violence          15
#
# [10 rows x 6 columns]
# (30677, 6)
# 0
# 10198
# 5961

# %% [markdown]
# We see that we have some speakers with very high average word counts, let's dig deeper.

# %%
avg_word_counts_par_speaker = df.groupby(['speaker'])[['Words count']].mean().reset_index()
print(avg_word_counts_par_speaker.shape)
avg_word_counts_par_speaker = avg_word_counts_par_speaker.sort_values('Words count', ascending=False)
avg_word_counts_par_speaker
# Out:
# (5961, 2)
#                speaker  Words count
# 1943  Freddie Hamilton        450.0
# 3727    Maria Cantwell        429.0
# 4731    Rebecca Solnit        416.0
# 1639  Donovan Mitchell        318.0
# 3768       Mark Greene        314.0
# ...                ...          ...
# 308      Anthony Beale          4.0
# 5674     Tom Deininger          4.0
# 917       Chesa Boudin          4.0
# 1764        Eli Saslow          4.0
# 3707      Marcus Ellis          4.0
#
# [5961 rows x 2 columns]

# %%
ax = avg_word_counts_par_speaker['Words count'].hist(log=True, bins=60, figsize=[30,10]);
ax.set_ylabel("Number of occurences");
ax.set_xlabel("Word count");
ax.set_title("Distribution of the average number of words per quotation for each speaker")

print(avg_word_counts_par_speaker[avg_word_counts_par_speaker['Words count'] > 250].count())
print(avg_word_counts_par_speaker[avg_word_counts_par_speaker['Words count'] < 3].count())
print(avg_word_counts_par_speaker[avg_word_counts_par_speaker['Words count'] < 4].count())
print(avg_word_counts_par_speaker[avg_word_counts_par_speaker['Words count'] < 5].count())
# Out:
# speaker        12
# Words count    12
# dtype: int64
# speaker        0
# Words count    0
# dtype: int64
# speaker        0
# Words count    0
# dtype: int64
# speaker        13
# Words count    13
# dtype: int64

# %% [markdown]
# We can see that most speakers have a low word counts, but a few of them have a very large number of words (in particular 12 for more than 250 words). We also observe that there are no speakers with less than 3 and 4 words and still a very low number for 5. This seems to point in a good direction for the coming sentimental analysis as phrases with more than 4 words could be more meaningful to intrepret and limit the possibilities of having a small number of unintelligable random words.

# %%
total_sum_word_counts_par_speaker = df.groupby(['speaker'])[['Words count']].sum().reset_index()
print(total_sum_word_counts_par_speaker.shape)
total_sum_word_counts_par_speaker = total_sum_word_counts_par_speaker.sort_values('Words count', ascending=False)
total_sum_word_counts_par_speaker
# Out:
# (5961, 2)
#                      speaker  Words count
# 4367                    None       330334
# 4628  President Barack Obama        11475
# 4281            Nancy Pelosi         9548
# 4636         President Obama         9367
# 2209         Hillary Clinton         8348
# ...                      ...          ...
# 5488         Susana Martinez            4
# 655              Brian Dugan            4
# 1966           Garret Graves            4
# 5674           Tom Deininger            4
# 570                 Bob Duff            4
#
# [5961 rows x 2 columns]

# %% [markdown]
# We see that the 'None' speakers yields the highest total words count which could have been expected given the relatively high share of quotes with unassigned speakers. We note that despite the high count the avg word count was not between the highest ones.
#
# #Note:
# We observe that some speakers may be present multiple times under slightly different name, for example "President Barack Obama" or "President Obama". This issue does not need to be treated here, since if and when we will study individual relevant speakers, we will only search part of their name, in this case "Obama" will suffice to detect any case of quotations from him. Additionally, this does not significantly alter any pre-processing or visual analysis done here.

# %%
ax = total_sum_word_counts_par_speaker['Words count'].hist(log=True, bins=60, figsize=[30,10]);
ax.set_ylabel("Number of occurences");
ax.set_xlabel("Word count");
ax.set_title("Distribution of the total number of words per quotation for each speaker");

# %% [markdown]
# We observe again in this graph that the unknown speakers make up for most of the total count of words.

# %%
desc = df.groupby(['speaker'])[['Words count']].describe().reset_index()
desc
# Out:
#                      speaker Words count             ...
#                                    count       mean  ...   50%    75%   max
# 0                  21 Savage         1.0  22.000000  ...  22.0  22.00  22.0
# 1                   A. Clark         6.0  35.833333  ...  32.5  48.75  61.0
# 2                  A. Harris         1.0  34.000000  ...  34.0  34.00  34.0
# 3                    A. King         1.0  71.000000  ...  71.0  71.00  71.0
# 4                   AJ Perez         1.0  19.000000  ...  19.0  19.00  19.0
# ...                      ...         ...        ...  ...   ...    ...   ...
# 5956  president Barack Obama        10.0  32.000000  ...  34.5  40.00  43.0
# 5957               ron Smith         1.0   7.000000  ...   7.0   7.00   7.0
# 5958           stacey newman         1.0  27.000000  ...  27.0  27.00  27.0
# 5959               tim kaine         1.0  36.000000  ...  36.0  36.00  36.0
# 5960                you long         1.0   9.000000  ...   9.0   9.00   9.0
#
# ...

# %% [markdown]
# Retrieve statistics grouped by unique speaker, could be useful for the sentimental analysis.

# %%
df_unk = df.query("speaker == 'None'")
desc = df_unk.groupby(['speaker'])[['Words count']].describe().reset_index()
desc
# Out:
#   speaker Words count
#                 count       mean        std  min   25%   50%   75%    max
# 0    None     10198.0  32.392038  28.848943  3.0  16.0  26.0  40.0  432.0

# %% [markdown]
# We can compare the describing statistics  only for unknown speakers quotes or with only assigned speakers. We do not observe any particular difference if not the fact that the total amount of words for the unkwown speakers is about half compared to the other situation. This suggests that the there is no particular difference in the quotation distributions in the two scenarios. We are happy as this might indicate that the two distributions are fundamentally similar and no observable bias linked to the machine learning algorithm has affected differently the matched and unmatched quotes with a particular speaker.

# %%
df_kno = df.query("speaker != 'None'")
df_kno['Words count'].describe().reset_index()
# Out:
#    index   Words count
# 0  count  20479.000000
# 1   mean     34.436984
# 2    std     27.997044
# 3    min      3.000000
# 4    25%     18.000000
# 5    50%     28.000000
# 6    75%     42.500000
# 7    max    450.000000

# %% [markdown]
# We run the same analysis for the case when we remove the quotes with unassigned spekers.

# %%
DATA_PATH = '/content/drive/MyDrive/projectada/processed_dfs/' 
def process_data(path, year, list_dfs):
  while year < 2020:
    for file in listdir(path + str(year) + '/'):
      small_df=pd.read_pickle(DATA_PATH + str(year) + '/' + file, compression='infer')
      filtered_small_df = small_df.query("(keyword == 'gun violence' | keyword == 'mass shooting' | keyword == 'firearm-related violence' | keyword == 'firearm violence') & speaker != 'None'")
      list_dfs.append(filtered_small_df)
    year += 1
  return list_dfs

list_dfs = []
data = pd.concat(process_data(DATA_PATH, 2015, list_dfs), ignore_index=True)

# %%
print(data.sample(10))
print(data.shape)
print(len(data[data.isna().any(axis=1)]))
print(data['speaker'].eq('None').sum())
print(data['speaker'].nunique())

data['quotation'] = data['quotation'].apply(lambda x: x.lower())
data['quotation'] = data['quotation'].replace('\d+', '', regex = True)
data['quotation'] = data['quotation'].replace('[^\w\s\+]', '', regex = True)
data['Words count'] = data['quotation'].apply(lambda x: len(str(x).split(' ')))
# Out:
#                       speaker  ...        keyword
# 12920               Bob Krist  ...   gun violence
# 7794       Gabrielle Giffords  ...   gun violence
# 14184          Julie Morrison  ...  mass shooting
# 19785              Eric Adams  ...   gun violence
# 15650             Chris Evans  ...   gun violence
# 15499            Sam Liccardo  ...   gun violence
# 1315           Marlon Kimpson  ...   gun violence
# 11346  Michelle Lujan Grisham  ...   gun violence
# 1980               Chuck Todd  ...   gun violence
# 13545              Ken Burton  ...   gun violence
#
# [10 rows x 5 columns]
# (20479, 5)
# 0
# 0
# 5960

# %%
avg_word_counts_par_speaker = data.groupby(['speaker'])[['Words count']].mean().reset_index()
print(avg_word_counts_par_speaker.shape)
avg_word_counts_par_speaker = avg_word_counts_par_speaker.sort_values('Words count', ascending=False)
avg_word_counts_par_speaker
# Out:
# (5960, 2)
#                speaker  Words count
# 1943  Freddie Hamilton        450.0
# 3727    Maria Cantwell        429.0
# 4730    Rebecca Solnit        416.0
# 1639  Donovan Mitchell        318.0
# 3768       Mark Greene        314.0
# ...                ...          ...
# 308      Anthony Beale          4.0
# 5673     Tom Deininger          4.0
# 917       Chesa Boudin          4.0
# 1764        Eli Saslow          4.0
# 3707      Marcus Ellis          4.0
#
# [5960 rows x 2 columns]

# %% [markdown]
# We do not observe any significant change compared with the case where the unkwown speakers were included.

# %%
ax = avg_word_counts_par_speaker['Words count'].hist(log=True, bins=60, figsize=[30,10]);
ax.set_ylabel("Number of occurences");
ax.set_xlabel("Word count");
ax.set_title("Distribution of the average number of words per quotation for each speaker");

print(avg_word_counts_par_speaker[avg_word_counts_par_speaker['Words count'] > 250].count())
print(avg_word_counts_par_speaker[avg_word_counts_par_speaker['Words count'] < 3].count())
print(avg_word_counts_par_speaker[avg_word_counts_par_speaker['Words count'] < 4].count())
print(avg_word_counts_par_speaker[avg_word_counts_par_speaker['Words count'] < 5].count())
# Out:
# speaker        12
# Words count    12
# dtype: int64
# speaker        0
# Words count    0
# dtype: int64
# speaker        0
# Words count    0
# dtype: int64
# speaker        13
# Words count    13
# dtype: int64

# %%
total_sum_word_counts_par_speaker = data.groupby(['speaker'])[['Words count']].sum().reset_index()
print(total_sum_word_counts_par_speaker.shape)
total_sum_word_counts_par_speaker = total_sum_word_counts_par_speaker.sort_values('Words count', ascending=False)
total_sum_word_counts_par_speaker
# Out:
# (5960, 2)
#                      speaker  Words count
# 4627  President Barack Obama        11475
# 4281            Nancy Pelosi         9548
# 4635         President Obama         9367
# 2209         Hillary Clinton         8348
# 970             Chris Murphy         6820
# ...                      ...          ...
# 5487         Susana Martinez            4
# 655              Brian Dugan            4
# 1966           Garret Graves            4
# 5673           Tom Deininger            4
# 570                 Bob Duff            4
#
# [5960 rows x 2 columns]

# %% [markdown]
# This plot looks way more intelligble now.

# %%
ax = total_sum_word_counts_par_speaker['Words count'].hist(log=True, bins=60, figsize=[30,10]);
ax.set_ylabel("Number of occurences");
ax.set_xlabel("Word count");
ax.set_title("Distribution of the total number of words per quotation for each speaker");

# %%
PATH_OUT = ''
df.to_pickle(PATH_OUT + "data.pkl", compression='infer', protocol=5)

# %% [markdown]
# ##Gun Violence Dataset
# For the mass shootings dataset, we first loaded all the years from the website and merged them in a single one.
# As of now, we will keep all the data as our first wish is to see whether events actually have an effect on the amount of quotes. For further analysis, we might select a subset of the data to focus on particular events. See the code below for initial loading, concatening and analysis of the guns dataset.

# %%
import seaborn as sns
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np

# %%
DATA_FOLDER = ''

MASS_SHOOTINGS_15 = DATA_FOLDER+"massshootings15.csv"
MASS_SHOOTINGS_16 = DATA_FOLDER+"massshootings16.csv"
MASS_SHOOTINGS_17 = DATA_FOLDER+"massshootings17.csv"
MASS_SHOOTINGS_18 = DATA_FOLDER+"massshootings18.csv"
MASS_SHOOTINGS_19 = DATA_FOLDER+"massshootings19.csv"
ACCIDENTS = DATA_FOLDER+"accidents.csv"

# %%
mass_shootings_15 = pd.read_csv(MASS_SHOOTINGS_15)
mass_shootings_16 = pd.read_csv(MASS_SHOOTINGS_16)
mass_shootings_17 = pd.read_csv(MASS_SHOOTINGS_17)
mass_shootings_18 = pd.read_csv(MASS_SHOOTINGS_18)
mass_shootings_19 = pd.read_csv(MASS_SHOOTINGS_19)
accidents = pd.read_csv(ACCIDENTS)

# %%
mass_shootings=pd.concat([mass_shootings_15, mass_shootings_16, mass_shootings_17, mass_shootings_18,
                          mass_shootings_19], ignore_index=True)

# %%
mass_shootings = mass_shootings.drop(columns=['State', 'City Or County', 'Address', 'Operations'])
mass_shootings['Category']='Mass Shooting'
mass_shootings['Incident Date'] = pd.to_datetime(mass_shootings['Incident Date'])
accidents = accidents.drop(columns=['State', 'City Or County', 'Address', 'Operations'])
accidents = accidents[~accidents['Incident Date'].str.contains("2021")]
accidents = accidents[~accidents['Incident Date'].str.contains("2020")]
accidents['Category']='Accident'
accidents['Incident Date'] = pd.to_datetime(accidents['Incident Date'])

# %%
mass_shootings.sort_values('# Killed', ascending=False).head()
# Out:
#       Incident ID Incident Date  # Killed  # Injured       Category
# 788        946496    2017-10-01        59        441  Mass Shooting
# 581        577157    2016-06-12        50         53  Mass Shooting
# 754        980577    2017-11-05        27         20  Mass Shooting
# 1574      1466705    2019-08-03        23         23  Mass Shooting
# 1372      1049217    2018-02-14        17         17  Mass Shooting

# %%
accidents.sort_values('# Killed', ascending=False).head()
# Out:
#       Incident ID Incident Date  # Killed  # Injured  Category
# 1058      1564937    2019-12-05         4          1  Accident
# 1400      1323697    2019-02-09         2          0  Accident
# 1985       926038    2017-09-02         2          0  Accident
# 1825      1031159    2018-01-19         2          0  Accident
# 1445      1289271    2018-12-31         2          0  Accident

# %%
mass_shootings.plot(x='Incident Date', y='# Killed', figsize=(20,10));

# %%
fig, axs = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(20, 10)
mass_shootings.plot(x='Incident Date', y='# Killed', figsize=(20,10), ax=axs[0], grid=True, color='c', legend=False);
data['date'].hist(figsize=(20,10), bins = 350, ax=axs[1]);
axs[0].set_title('Shooting_event');
axs[0].set_ylabel('Number of people killed per mass shooting event');
axs[1].set_title('Quotes');
axs[1].set_ylabel('Number of gunshot violence related quotes');

# %%
fig, axs = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(20, 10)
mass_shootings.plot(x='Incident Date', y='# Killed', figsize=(20,10), ax=axs[0], grid=True, color='c', legend=False);
data['date'].hist(figsize=(20,10), bins = 250, ax=axs[1]);
axs[0].set_title('Shooting_event');
axs[0].set_ylabel('Number of people killed per mass shooting event');
axs[1].set_title('Quotes');
axs[1].set_ylabel('Number of gunshot violence related quotes');

# %%
fig, axs = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(20, 10)
mass_shootings.plot(x='Incident Date', y='# Killed', figsize=(20,10), ax=axs[0], grid=True, color='c', legend=False);
data['date'].hist(figsize=(20,10), bins = 150, ax=axs[1]);
axs[0].set_title('Shooting_event');
axs[0].set_ylabel('Number of people killed per mass shooting event');
axs[1].set_title('Quotes');
axs[1].set_ylabel('Number of gunshot violence related quotes');

# %% [markdown]
# From a visual inspection there seems to be some rough correlation (with those more or less corresponding peaks, exception raised for the second highest peak in the shooting event dataset) between the number of people killed per shooting event and a relatively high number of gunshot violence related quotes in similar dates.
#
# We explored different bin sizes and we do not observe significant changes in the overall bars distributions for the quotes.
